# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("salary.csv")
data.head(30)
# Out:
#     Year_of_Exp  Salary
# 0           1.0   10000
# 1           1.3   15000
# 2           1.6   21000
# 3           2.0   21000
# 4           2.6   30000
# 5           2.9   30000
# 6           3.0   40000
# 7           3.3   45000
# 8           3.9   55000
# 9           4.5   55000
# 10          4.8   59000
# 11          5.0   63000
# 12          5.4   65000
# 13          5.7   70000
# 14          6.0   70000
# 15          6.8   79000
# 16          7.0   83000
# 17          7.9   89000
# 18          8.2   91000
# 19          8.8   97000
# 20          9.0  100000
# 21          9.7  105000
# 22         10.0  115000
# 23         10.4  120000
# 24         11.0  120000
# 25         11.6  133000
# 26         12.0  140000
# 27         12.5  145000
# 28         13.0  150000
# 29         13.5  150000

# %%
# x y value 
real_x = data.iloc[:,0].values
real_y = data.iloc[:,1].values
# convert in 2D array from 1D array
real_x=real_x.reshape(-1,1)
real_y=real_y.reshape(-1,1)
print(real_x)
# Out:
# [[ 1. ]
#  [ 1.3]
#  [ 1.6]
#  [ 2. ]
#  [ 2.6]
#  [ 2.9]
#  [ 3. ]
#  [ 3.3]
#  [ 3.9]
#  [ 4.5]
#  [ 4.8]
#  [ 5. ]
#  [ 5.4]
#  [ 5.7]
#  [ 6. ]
#  [ 6.8]
#  [ 7. ]
#  [ 7.9]
#  [ 8.2]
#  [ 8.8]
#  [ 9. ]
#  [ 9.7]
#  [10. ]
#  [10.4]
#  [11. ]
#  [11.6]
#  [12. ]
#  [12.5]
#  [13. ]
#  [13.5]
#  [14. ]
#  [14.5]
#  [15. ]
#  [15.6]
#  [16. ]
#  [16.8]
#  [17.5]
#  [18. ]
#  [18.5]]

# %%
# divide dataset in the form of testing and traning
# 70% for training 
# 30 % for testing

training_x,testing_x,training_y,testing_y=train_test_split(real_x,real_y,test_size=0.3,random_state=0)

# %%
# Fit Model
Lin = LinearRegression()
Lin.fit(training_x,training_y)
print("Training successfull..!!!")
# Out:
# Training successfull..!!!

# %%
# Prediction

Pred_y = Lin.predict(testing_x)

# %%
# check Actual Value 
testing_y[10]
# Out:
# array([91000])

# %%
# this is Predictor value .......................
Pred_y[10]
# Out:
# array([88538.04174569])

# %%
# Another method for prediction 

# y = b1x + b0

Lin.coef_
 # this is b1 value
# Out:
# array([[9943.31966305]])

# %%
Lin.intercept_

# this is b0 value
# Out:
# array([7002.82050866])

# %%
# put in equ
# coef + intercept
9943.31966305 * 3 +  7002.82050866
# Out:
# 36832.77949781

# %%
plt.scatter(training_x,training_y,color='green')
plt.plot(training_x,Lin.predict(training_x),color='blue')
plt.title("Salary & Exp Training Plot")
plt.xlabel("Exp")
plt.ylabel("Salary")
plt.show()

# %%
plt.scatter(testing_x,testing_y,color='green')
plt.plot(training_x,Lin.predict(training_x),color='blue')
plt.title("Salary & Exp testing Plot")
plt.xlabel("Exp")
plt.ylabel("Salary")
plt.show()


# using OLS(ordinary least square)
