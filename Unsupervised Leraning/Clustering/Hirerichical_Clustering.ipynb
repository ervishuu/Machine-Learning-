# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Mall_Customers.csv")
data.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
real_x = data.iloc[: , [3,4]].values

# %%
import scipy.cluster.hierarchy as sch_clus

# %%
sch_clus.dendrogram(sch_clus.linkage(real_x , method = "ward"))
plt.title("Dendogram")
plt.xlabel("Customers")
plt.ylabel("Euclidean Distance")
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
h_c = AgglomerativeClustering(n_clusters=5 , affinity = "euclidean" , linkage = "ward")
pred_h_c = h_c.fit_predict(real_x)

# %%
size = 40 
plt.scatter(real_x[pred_h_c == 0,0],real_x[pred_h_c == 0,1],s = size , c = "red")
plt.scatter(real_x[pred_h_c == 1,0],real_x[pred_h_c == 1,1],s = size , c = "yellow")
plt.scatter(real_x[pred_h_c == 2,0],real_x[pred_h_c == 2,1],s = size , c = "green")
plt.scatter(real_x[pred_h_c == 3,0],real_x[pred_h_c == 3,1],s = size , c = "orange")
plt.scatter(real_x[pred_h_c == 4,0],real_x[pred_h_c == 4,1],s = size , c = "blue")

plt.title("Cluster")
plt.xlabel("Anual Income")
plt.ylabel("Spending Salary")
plt.show()
